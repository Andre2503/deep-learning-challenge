# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dla-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN", "NAME"])

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_value = application_df.groupby ('APPLICATION_TYPE')['APPLICATION_TYPE'].count()
application_type_value
# Out:
# APPLICATION_TYPE
# T10      528
# T12       27
# T13       66
# T14        3
# T15        2
# T17        1
# T19     1065
# T2        16
# T25        3
# T29        2
# T3     27037
# T4      1542
# T5      1173
# T6      1216
# T7       725
# T8       737
# T9       156
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = []

# Iterate through the series
for app_name, count in application_type_value.items():
    if count < 737:
        application_types_to_replace.append(app_name)

# application_names now contains the names with counts less than 500
print(application_types_to_replace)
# Out:
# ['T10', 'T12', 'T13', 'T14', 'T15', 'T17', 'T2', 'T25', 'T29', 'T7', 'T9']

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# Other     7262
# Name: APPLICATION_TYPE, dtype: int64

# %%
# look at CLASSIFICATION value counts >1
filtered_classifications = class_value_types[class_value_types > 1]
filtered_classifications
# Out:
# CLASSIFICATION
# C0           3
# C1000    17326
# C1200     4837
# C1230       36
# C1234        2
# C1235        9
# C1237        9
# C1238       10
# C1240       30
# C1246        2
# C1250       14
# C1256        2
# C1257        5
# C1260        3
# C1267        2
# C1270      114
# C1278       10
# C1280       50
# C1300       58
# C1400       34
# C1500       16
# C1600        5
# C1700      287
# C1720        6
# C1800       15
# C2000     6074
# C2100     1883
# C2300       32
# C2400        6
# C2700      104
# C2710        3
# C2800       95
# C3000     1918
# C3200        2
# C4000      194
# C4100        6
# C5000      116
# C6000       15
# C7000      777
# C7100       75
# C7120       18
# C7200       32
# C7210        7
# C8000       20
# C8200       11
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

classifications_to_replace = [] #empty list to hold results

for class_name, count in class_value_types.items():   #for loop through series to ID class types with count less than 700.
  if count < 194:
    classifications_to_replace.append(class_name)

#print result for verification
print(classifications_to_replace)
# Out:
# ['C0', 'C1230', 'C1234', 'C1235', 'C1236', 'C1237', 'C1238', 'C1240', 'C1245', 'C1246', 'C1248', 'C1250', 'C1256', 'C1257', 'C1260', 'C1267', 'C1270', 'C1278', 'C1280', 'C1283', 'C1300', 'C1370', 'C1400', 'C1500', 'C1570', 'C1580', 'C1600', 'C1720', 'C1728', 'C1732', 'C1800', 'C1820', 'C1900', 'C2150', 'C2170', 'C2190', 'C2300', 'C2380', 'C2400', 'C2500', 'C2561', 'C2570', 'C2600', 'C2700', 'C2710', 'C2800', 'C3200', 'C3700', 'C4100', 'C4120', 'C4200', 'C4500', 'C5000', 'C5200', 'C6000', 'C6100', 'C7100', 'C7120', 'C7200', 'C7210', 'C8000', 'C8200', 'C8210']

# %%
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# Other     6062
# C1200     4837
# Name: CLASSIFICATION, dtype: int64

# %%
#access info for easy access to features that need to be converted to numerical
application_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   APPLICATION_TYPE        34299 non-null  object
#  1   AFFILIATION             34299 non-null  object
#  2   CLASSIFICATION          34299 non-null  object
#  3   USE_CASE                34299 non-null  object
#  4   ORGANIZATION            34299 non-null  object
#  5   STATUS                  34299 non-null  int64
#  6   INCOME_AMT              34299 non-null  object
#  7   SPECIAL_CONSIDERATIONS  34299 non-null  object
#  8   ASK_AMT                 34299 non-null  int64
#  9   IS_SUCCESSFUL           34299 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 2.6+ MB

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies_df = pd.get_dummies(application_df[['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS']])
dummies_df.head()
# Out:
#    APPLICATION_TYPE_Other  APPLICATION_TYPE_T3  AFFILIATION_CompanySponsored  \
# 0                       1                    0                             0
# 1                       0                    1                             0
# 2                       1                    0                             1
# 3                       0                    1                             1
# 4                       0                    1                             0
#
#    AFFILIATION_Family/Parent  AFFILIATION_Independent  AFFILIATION_National  \
# 0                          0                        1                     0
# 1                          0                        1                     0
# 2                          0                        0                     0
# 3                          0                        0                     0
# 4                          0                        1                     0
#
#    AFFILIATION_Other  AFFILIATION_Regional  CLASSIFICATION_C1000  \
# 0                  0                     0                     1
# 1                  0                     0                     0
# 2                  0                     0                     0
# 3                  0                     0                     0
# 4                  0                     0                     1
#
#    CLASSIFICATION_C1200  ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# 0                     0  ...                  0                       0
# 1                     0  ...                  1                       0
# 2                     0  ...                  0                       0
# 3                     0  ...                  0                       1
# 4                     0  ...                  0                       0
#
#    INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 0                         0                   0                 0
# 1                         0                   0                 0
# 2                         0                   0                 0
# 3                         0                   0                 0
# 4                         1                   0                 0
#
#    INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M  \
# 0                       0                0                  0
# 1                       0                0                  0
# 2                       0                0                  0
# 3                       0                0                  0
# 4                       0                0                  0
#
#    SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                         1                         0
# 1                         1                         0
# 2                         1                         0
# 3                         1                         0
# 4                         1                         0
#
# [5 rows x 32 columns]

# %%
#diplay info of new df dummies_df
dummies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   APPLICATION_TYPE_Other        34299 non-null  uint8
#  1   APPLICATION_TYPE_T3           34299 non-null  uint8
#  2   AFFILIATION_CompanySponsored  34299 non-null  uint8
#  3   AFFILIATION_Family/Parent     34299 non-null  uint8
#  4   AFFILIATION_Independent       34299 non-null  uint8
#  5   AFFILIATION_National          34299 non-null  uint8
#  6   AFFILIATION_Other             34299 non-null  uint8
#  7   AFFILIATION_Regional          34299 non-null  uint8
#  8   CLASSIFICATION_C1000          34299 non-null  uint8
#  9   CLASSIFICATION_C1200          34299 non-null  uint8
#  10  CLASSIFICATION_C2000          34299 non-null  uint8
#  11  CLASSIFICATION_Other          34299 non-null  uint8
#  12  USE_CASE_CommunityServ        34299 non-null  uint8
#  13  USE_CASE_Heathcare            34299 non-null  uint8
#  14  USE_CASE_Other                34299 non-null  uint8
#  15  USE_CASE_Preservation         34299 non-null  uint8
#  16  USE_CASE_ProductDev           34299 non-null  uint8
#  17  ORGANIZATION_Association      34299 non-null  uint8
#  18  ORGANIZATION_Co-operative     34299 non-null  uint8
#  19  ORGANIZATION_Corporation      34299 non-null  uint8
#  20  ORGANIZATION_Trust            34299 non-null  uint8
#  21  INCOME_AMT_0                  34299 non-null  uint8
#  22  INCOME_AMT_1-9999             34299 non-null  uint8
#  23  INCOME_AMT_10000-24999        34299 non-null  uint8
#  24  INCOME_AMT_100000-499999      34299 non-null  uint8
#  25  INCOME_AMT_10M-50M            34299 non-null  uint8
#  26  INCOME_AMT_1M-5M              34299 non-null  uint8
#  27  INCOME_AMT_25000-99999        34299 non-null  uint8
#  28  INCOME_AMT_50M+               34299 non-null  uint8
#  29  INCOME_AMT_5M-10M             34299 non-null  uint8
#  30  SPECIAL_CONSIDERATIONS_N      34299 non-null  uint8
#  31  SPECIAL_CONSIDERATIONS_Y      34299 non-null  uint8
# dtypes: uint8(32)
# memory usage: 1.0 MB

# %%
# concatenate the application_df and the dummies_df
application_df_processed = pd.concat([application_df[['ASK_AMT', 'IS_SUCCESSFUL']], dummies_df], axis=1)
application_df_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34299 entries, 0 to 34298
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ASK_AMT                       34299 non-null  int64
#  1   IS_SUCCESSFUL                 34299 non-null  int64
#  2   APPLICATION_TYPE_Other        34299 non-null  uint8
#  3   APPLICATION_TYPE_T3           34299 non-null  uint8
#  4   AFFILIATION_CompanySponsored  34299 non-null  uint8
#  5   AFFILIATION_Family/Parent     34299 non-null  uint8
#  6   AFFILIATION_Independent       34299 non-null  uint8
#  7   AFFILIATION_National          34299 non-null  uint8
#  8   AFFILIATION_Other             34299 non-null  uint8
#  9   AFFILIATION_Regional          34299 non-null  uint8
#  10  CLASSIFICATION_C1000          34299 non-null  uint8
#  11  CLASSIFICATION_C1200          34299 non-null  uint8
#  12  CLASSIFICATION_C2000          34299 non-null  uint8
#  13  CLASSIFICATION_Other          34299 non-null  uint8
#  14  USE_CASE_CommunityServ        34299 non-null  uint8
#  15  USE_CASE_Heathcare            34299 non-null  uint8
#  16  USE_CASE_Other                34299 non-null  uint8
#  17  USE_CASE_Preservation         34299 non-null  uint8
#  18  USE_CASE_ProductDev           34299 non-null  uint8
#  19  ORGANIZATION_Association      34299 non-null  uint8
#  20  ORGANIZATION_Co-operative     34299 non-null  uint8
#  21  ORGANIZATION_Corporation      34299 non-null  uint8
#  22  ORGANIZATION_Trust            34299 non-null  uint8
#  23  INCOME_AMT_0                  34299 non-null  uint8
#  24  INCOME_AMT_1-9999             34299 non-null  uint8
#  25  INCOME_AMT_10000-24999        34299 non-null  uint8
#  26  INCOME_AMT_100000-499999      34299 non-null  uint8
#  27  INCOME_AMT_10M-50M            34299 non-null  uint8
#  28  INCOME_AMT_1M-5M              34299 non-null  uint8
#  29  INCOME_AMT_25000-99999        34299 non-null  uint8
#  30  INCOME_AMT_50M+               34299 non-null  uint8
#  31  INCOME_AMT_5M-10M             34299 non-null  uint8
#  32  SPECIAL_CONSIDERATIONS_N      34299 non-null  uint8
#  33  SPECIAL_CONSIDERATIONS_Y      34299 non-null  uint8
# dtypes: int64(2), uint8(32)
# memory usage: 1.6 MB

# %%
# Split our preprocessed data into our features and target arrays
y = application_df_processed['IS_SUCCESSFUL'].values
X = application_df_processed.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer

nn.add(tf.keras.layers.Dense(units=8, activation='tanh', input_dim=33))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=10, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_37 (Dense)            (None, 8)                 272
#
#  dense_38 (Dense)            (None, 10)                90
#
#  dense_39 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 373 (1.46 KB)
# Trainable params: 373 (1.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5750 - accuracy: 0.7135
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5748 - accuracy: 0.7144
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5749 - accuracy: 0.7137
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5748 - accuracy: 0.7140
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5747 - accuracy: 0.7144
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5751 - accuracy: 0.7121
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5748 - accuracy: 0.7138
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5748 - accuracy: 0.7142
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5748 - accuracy: 0.7142
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5747 - accuracy: 0.7145
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5749 - accuracy: 0.7138
# Epoch 12/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5745 - accuracy: 0.7137
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5747 - accuracy: 0.7141
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5747 - accuracy: 0.7135
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5748 - accuracy: 0.7147
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5747 - accuracy: 0.7142
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5746 - accuracy: 0.7138
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5744 - accuracy: 0.7146
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5745 - accuracy: 0.7143
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5743 - accuracy: 0.7147
# Epoch 21/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5744 - accuracy: 0.7144
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5745 - accuracy: 0.7137
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5743 - accuracy: 0.7143
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5745 - accuracy: 0.7146
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5744 - accuracy: 0.7144
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5744 - accuracy: 0.7144
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5741 - accuracy: 0.7128
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5742 - accuracy: 0.7146
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5743 - accuracy: 0.7143
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5741 - accuracy: 0.7142
# Epoch 31/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5741 - accuracy: 0.7137
# Epoch 32/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5742 - accuracy: 0.7145
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5742 - accuracy: 0.7141
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5744 - accuracy: 0.7149
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5742 - accuracy: 0.7147
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5740 - accuracy: 0.7147
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5741 - accuracy: 0.7147
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5740 - accuracy: 0.7150
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5740 - accuracy: 0.7151
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5741 - accuracy: 0.7145
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5741 - accuracy: 0.7144
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5740 - accuracy: 0.7146
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5739 - accuracy: 0.7149
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5742 - accuracy: 0.7147
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5741 - accuracy: 0.7147
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5741 - accuracy: 0.7147
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5737 - accuracy: 0.7146
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5740 - accuracy: 0.7152
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5741 - accuracy: 0.7144
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5739 - accuracy: 0.7154
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5739 - accuracy: 0.7149
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5737 - accuracy: 0.7149
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5739 - accuracy: 0.7152
# Epoch 54/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5737 - accuracy: 0.7144
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5738 - accuracy: 0.7149
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5738 - accuracy: 0.7148
# Epoch 57/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5737 - accuracy: 0.7144
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5740 - accuracy: 0.7158
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5738 - accuracy: 0.7157
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5738 - accuracy: 0.7152
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5738 - accuracy: 0.7157
# Epoch 62/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5738 - accuracy: 0.7154
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5739 - accuracy: 0.7146
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5737 - accuracy: 0.7156
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5738 - accuracy: 0.7147
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5737 - accuracy: 0.7151
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5739 - accuracy: 0.7146
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5736 - accuracy: 0.7153
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5736 - accuracy: 0.7152
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5736 - accuracy: 0.7147
# Epoch 71/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5737 - accuracy: 0.7150
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5736 - accuracy: 0.7152
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5734 - accuracy: 0.7152
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5738 - accuracy: 0.7146
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5737 - accuracy: 0.7155
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5738 - accuracy: 0.7151
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5735 - accuracy: 0.7154
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5734 - accuracy: 0.7154
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5736 - accuracy: 0.7146
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5734 - accuracy: 0.7149
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5735 - accuracy: 0.7152
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5738 - accuracy: 0.7156
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5735 - accuracy: 0.7154
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5736 - accuracy: 0.7149
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5735 - accuracy: 0.7153
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5734 - accuracy: 0.7149
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5734 - accuracy: 0.7154
# Epoch 88/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5736 - accuracy: 0.7148
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5735 - accuracy: 0.7158
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5734 - accuracy: 0.7159
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5734 - accuracy: 0.7150
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5733 - accuracy: 0.7151
# Epoch 93/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5733 - accuracy: 0.7154
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5735 - accuracy: 0.7165
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5735 - accuracy: 0.7142
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5733 - accuracy: 0.7156
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5733 - accuracy: 0.7154
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5733 - accuracy: 0.7155
# Epoch 99/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5733 - accuracy: 0.7156
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5734 - accuracy: 0.7157

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5824 - accuracy: 0.7082 - 348ms/epoch - 1ms/step
# Loss: 0.5823875069618225, Accuracy: 0.7082215547561646

# %% [markdown]
# #**#Second Model**

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn2 = tf.keras.models.Sequential()

# First hidden layer

nn2.add(tf.keras.layers.Dense(units=8, activation='tanh', input_dim=33))

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=8, activation="relu"))

# Third hidden layer
nn2.add(tf.keras.layers.Dense(units=8, activation="relu"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 8)                 272
#
#  dense_41 (Dense)            (None, 8)                 72
#
#  dense_42 (Dense)            (None, 8)                 72
#
#  dense_43 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 425 (1.66 KB)
# Trainable params: 425 (1.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model2 = nn2.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6144 - accuracy: 0.6827
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5911 - accuracy: 0.6988
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5869 - accuracy: 0.7024
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5845 - accuracy: 0.7072
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5830 - accuracy: 0.7074
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5819 - accuracy: 0.7096
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5812 - accuracy: 0.7085
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5804 - accuracy: 0.7098
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5799 - accuracy: 0.7096
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5793 - accuracy: 0.7118
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5790 - accuracy: 0.7117
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5789 - accuracy: 0.7111
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5787 - accuracy: 0.7116
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5782 - accuracy: 0.7123
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5783 - accuracy: 0.7119
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5781 - accuracy: 0.7123
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5775 - accuracy: 0.7132
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5772 - accuracy: 0.7123
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5773 - accuracy: 0.7131
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5770 - accuracy: 0.7123
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5768 - accuracy: 0.7117
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5772 - accuracy: 0.7132
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5768 - accuracy: 0.7133
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5770 - accuracy: 0.7136
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5767 - accuracy: 0.7142
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5767 - accuracy: 0.7135
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.